# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels
import statsmodels.formula.api as smf

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Wendy611/QM/main/full_data.csv")
df.head()
# Out:
#    Unnamed: 0       ward               borough  \
# 0           1  E05000026  Barking and Dagenham
# 1           2  E05000027  Barking and Dagenham
# 2           3  E05000028  Barking and Dagenham
# 3           4  E05000029  Barking and Dagenham
# 4           5  E05000030  Barking and Dagenham
#
#    %_english_is_first_language_of_no_one_in_household_2011  \
# 0                                               25.7
# 1                                                7.9
# 2                                               10.5
# 3                                                6.5
# 4                                                4.5
#
#    median_house_price_2014  median_household_income_estimate_2012_13  \
# 0                 173000.0                                   33920.0
# 1                 215000.0                                   32470.0
# 2                 210000.0                                   33000.0
# 3                 240500.0                                   33920.0
# 4                 240000.0                                   37400.0
#
#    male_life_expectancy_2009_13  female_life_expectancy_2009_13  \
# 0                          80.2                            83.9
# 1                          77.2                            80.6
# 2                          79.0                            79.3
# 3                          79.2                            82.2
# 4                          77.1                            81.1
#
#    %_area_that_is_open_space_2014  %_travel_by_bicycle_to_work_2011  \
# 0                            21.9                               0.8
# 1                            20.6                               1.0
# 2                             1.9                               1.6
# 3                            56.0                               1.2
# 4                            50.4                               1.6
#
#    turnout_at_mayoral_election_2012  crime_rate_2014_15  %_bame_2011  \
# 0                              25.7               138.1         71.9
# 1                              20.3                73.6         29.9
# 2                              22.5                79.9         41.2
# 3                              25.3                76.1         37.9
# 4                              24.1                66.7         24.8
#
#    %_all_older_people_aged_65_2015  %_homes_with_good_access_to_nature  \
# 0                              5.0                                98.0
# 1                             10.0                                28.0
# 2                              8.7                                83.0
# 3                             14.2                                36.0
# 4                             14.2                               100.0
#
#    %_homes_with_deficiency_in_access_to_nature  \
# 0                                          2.0
# 1                                         72.0
# 2                                         17.0
# 3                                         64.0
# 4                                          0.0
#
#    female_life_expectancy_normalised  male_life_expectancy_normalised
# 0                           0.996498                         1.005313
# 1                           0.957303                         0.967708
# 2                           0.941863                         0.990271
# 3                           0.976306                         0.992778
# 4                           0.963242                         0.966455

# %%
print("df.shape: ", df.shape)
# Out:
# df.shape:  (624, 18)

# %%
size = len(df)

older_mean = df['%_all_older_people_aged_65_2015'].mean()
older_median = df['%_all_older_people_aged_65_2015'].median()
older_min = df['%_all_older_people_aged_65_2015'].min()
older_max = df['%_all_older_people_aged_65_2015'].max()
older_people_percent_range = older_max - older_min
variance = df['%_all_older_people_aged_65_2015'].var()
std_dev = df['%_all_older_people_aged_65_2015'].std()

print("size of dataset:",size)
print("mean:", round(older_mean, 2))
print("median:", older_median)
print("min:", older_min)
print("max:", older_max)
print("range:", older_people_percent_range)
print("variance:", round(variance, 3))
print("standard deviation:", round(std_dev, 3))
# Out:
# size of dataset: 624
# mean: 11.79
# median: 11.1
# min: 3.7
# max: 24.3
# range: 20.6
# variance: 18.192
# standard deviation: 4.265

# %%
df.boxplot(column='%_all_older_people_aged_65_2015')
# Out:
# <AxesSubplot:>

# %%
df['%_all_older_people_aged_65_2015'].plot.hist(grid=True, bins=20, rwidth=0.9,
                                               color='#B0C4DE')
plt.title('Percentage of people over 65 years old in 2015')
plt.xlabel('percentage of people over 65 years old')
plt.ylabel('count')

plt.grid(axis='x')
plt.axvline(older_mean, color='k', linestyle='dashed')
min_ylim, max_ylim = plt.ylim()
plt.text(older_mean*1.1, max_ylim*0.9, 'Mean:{:.2f}'.format(older_mean))
# Out:
# Text(12.97136217948718, 63.315, 'Mean:11.79')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ward', 'borough',
#        '%_english_is_first_language_of_no_one_in_household_2011',
#        'median_house_price_2014', 'median_household_income_estimate_2012_13',
#        'male_life_expectancy_2009_13', 'female_life_expectancy_2009_13',
#        '%_area_that_is_open_space_2014', '%_travel_by_bicycle_to_work_2011',
#        'turnout_at_mayoral_election_2012', 'crime_rate_2014_15', '%_bame_2011',
#        '%_all_older_people_aged_65_2015', '%_homes_with_good_access_to_nature',
#        '%_homes_with_deficiency_in_access_to_nature',
#        'female_life_expectancy_normalised', 'male_life_expectancy_normalised'],
#       dtype='object')

# %%
df = df.rename(columns={'median_household_income_estimate_2012_13': 'income',
                       'turnout_at_mayoral_election_2012': 'turnout'})

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ward', 'borough',
#        '%_english_is_first_language_of_no_one_in_household_2011',
#        'median_house_price_2014', 'income', 'male_life_expectancy_2009_13',
#        'female_life_expectancy_2009_13', '%_area_that_is_open_space_2014',
#        '%_travel_by_bicycle_to_work_2011', 'turnout', 'crime_rate_2014_15',
#        '%_bame_2011', '%_all_older_people_aged_65_2015',
#        '%_homes_with_good_access_to_nature',
#        '%_homes_with_deficiency_in_access_to_nature',
#        'female_life_expectancy_normalised', 'male_life_expectancy_normalised'],
#       dtype='object')

# %%
df.plot(kind='scatter', x='income', y='turnout', figsize=(20, 12))
# Out:
# <AxesSubplot:xlabel='income', ylabel='turnout'>

# %%
df.corr()
# Out:
#                                                     Unnamed: 0  \
# Unnamed: 0                                            1.000000
# %_english_is_first_language_of_no_one_in_househ...    0.093328
# median_house_price_2014                               0.194366
# income                                                0.167865
# male_life_expectancy_2009_13                         -0.030050
# female_life_expectancy_2009_13                       -0.036006
# %_area_that_is_open_space_2014                       -0.086308
# %_travel_by_bicycle_to_work_2011                      0.257197
# turnout                                               0.083252
# crime_rate_2014_15                                    0.121451
# %_bame_2011                                           0.060438
# %_all_older_people_aged_65_2015                      -0.255443
# %_homes_with_good_access_to_nature                   -0.024884
# %_homes_with_deficiency_in_access_to_nature           0.024884
# female_life_expectancy_normalised                    -0.036006
# male_life_expectancy_normalised                      -0.030050
#
#                                                     %_english_is_first_language_of_no_one_in_household_2011  \
# Unnamed: 0                                                                                   0.093328
# %_english_is_first_language_of_no_one_in_househ...                                           1.000000
# median_house_price_2014                                                                      0.138404
# income                                                                                      -0.250155
# male_life_expectancy_2009_13                                                                -0.103185
# female_life_expectancy_2009_13                                                              -0.069790
# %_area_that_is_open_space_2014                                                              -0.314778
# %_travel_by_bicycle_to_work_2011                                                             0.025750
# turnout                                                                                     -0.251114
# crime_rate_2014_15                                                                           0.251044
# %_bame_2011                                                                                  0.749317
# %_all_older_people_aged_65_2015                                                             -0.543030
# %_homes_with_good_access_to_nature                                                          -0.208124
# %_homes_with_deficiency_in_access_to_nature                                                  0.208124
# female_life_expectancy_normalised                                                           -0.069790
# male_life_expectancy_normalised                                                             -0.103185
#
#                                                     median_house_price_2014  \
# Unnamed: 0                                                         0.194366
# %_english_is_first_language_of_no_one_in_househ...                 0.138404
# median_house_price_2014                                            1.000000
# income                                                             0.774241
# male_life_expectancy_2009_13                                       0.460097
# female_life_expectancy_2009_13                                     0.406423
# %_area_that_is_open_space_2014                                    -0.067367
# %_travel_by_bicycle_to_work_2011                                   0.308735
# turnout                                                            0.262742
# crime_rate_2014_15                                                 0.302794
# %_bame_2011                                                       -0.278767
# %_all_older_people_aged_65_2015                                    0.085899
# %_homes_with_good_access_to_nature                                 0.077526
# %_homes_with_deficiency_in_access_to_nature                       -0.077526
# female_life_expectancy_normalised                                  0.406423
# male_life_expectancy_normalised                                    0.460097
#
#                                                       income  \
# Unnamed: 0                                          0.167865
# %_english_is_first_language_of_no_one_in_househ... -0.250155
# median_house_price_2014                             0.774241
# income                                              1.000000
# male_life_expectancy_2009_13                        0.648198
# female_life_expectancy_2009_13                      0.506527
# %_area_that_is_open_space_2014                      0.018869
# %_travel_by_bicycle_to_work_2011                    0.220767
# turnout                                             0.510309
# crime_rate_2014_15                                  0.075341
# %_bame_2011                                        -0.588628
# %_all_older_people_aged_65_2015                     0.338609
# %_homes_with_good_access_to_nature                  0.168295
# %_homes_with_deficiency_in_access_to_nature        -0.168295
# female_life_expectancy_normalised                   0.506527
# male_life_expectancy_normalised                     0.648198
#
#                                                     male_life_expectancy_2009_13  \
# Unnamed: 0                                                             -0.030050
# %_english_is_first_language_of_no_one_in_househ...                     -0.103185
# median_house_price_2014                                                 0.460097
# income                                                                  0.648198
# male_life_expectancy_2009_13                                            1.000000
# female_life_expectancy_2009_13                                          0.705725
# %_area_that_is_open_space_2014                                          0.076994
# %_travel_by_bicycle_to_work_2011                                       -0.184221
# turnout                                                                 0.399158
# crime_rate_2014_15                                                     -0.074633
# %_bame_2011                                                            -0.333248
# %_all_older_people_aged_65_2015                                         0.525190
# %_homes_with_good_access_to_nature                                      0.141751
# %_homes_with_deficiency_in_access_to_nature                            -0.141751
# female_life_expectancy_normalised                                       0.705725
# male_life_expectancy_normalised                                         1.000000
#
#                                                     female_life_expectancy_2009_13  \
# Unnamed: 0                                                               -0.036006
# %_english_is_first_language_of_no_one_in_househ...                       -0.069790
# median_house_price_2014                                                   0.406423
# income                                                                    0.506527
# male_life_expectancy_2009_13                                              0.705725
# female_life_expectancy_2009_13                                            1.000000
# %_area_that_is_open_space_2014                                            0.036027
# %_travel_by_bicycle_to_work_2011                                         -0.050849
# turnout                                                                   0.348662
# crime_rate_2014_15                                                       -0.053537
# %_bame_2011                                                              -0.268129
# %_all_older_people_aged_65_2015                                           0.393078
# %_homes_with_good_access_to_nature                                        0.105695
# %_homes_with_deficiency_in_access_to_nature                              -0.105695
# female_life_expectancy_normalised                                         1.000000
# male_life_expectancy_normalised                                           0.705725
#
#                                                     %_area_that_is_open_space_2014  \
# Unnamed: 0                                                               -0.086308
# %_english_is_first_language_of_no_one_in_househ...                       -0.314778
# median_house_price_2014                                                  -0.067367
# income                                                                    0.018869
# male_life_expectancy_2009_13                                              0.076994
# female_life_expectancy_2009_13                                            0.036027
# %_area_that_is_open_space_2014                                            1.000000
# %_travel_by_bicycle_to_work_2011                                         -0.221545
# turnout                                                                  -0.009107
# crime_rate_2014_15                                                       -0.165776
# %_bame_2011                                                              -0.243978
# %_all_older_people_aged_65_2015                                           0.346641
# %_homes_with_good_access_to_nature                                        0.239199
# %_homes_with_deficiency_in_access_to_nature                              -0.239199
# female_life_expectancy_normalised                                         0.036027
# male_life_expectancy_normalised                                           0.076994
#
#                                                     %_travel_by_bicycle_to_work_2011  \
# Unnamed: 0                                                                  0.257197
# %_english_is_first_language_of_no_one_in_househ...                          0.025750
# median_house_price_2014                                                     0.308735
# income                                                                      0.220767
# male_life_expectancy_2009_13                                               -0.184221
# female_life_expectancy_2009_13                                             -0.050849
# %_area_that_is_open_space_2014                                             -0.221545
# %_travel_by_bicycle_to_work_2011                                            1.000000
# turnout                                                                     0.279535
# crime_rate_2014_15                                                          0.165574
# %_bame_2011                                                                -0.094914
# %_all_older_people_aged_65_2015                                            -0.443925
# %_homes_with_good_access_to_nature                                          0.000637
# %_homes_with_deficiency_in_access_to_nature                                -0.000637
# female_life_expectancy_normalised                                          -0.050849
# male_life_expectancy_normalised                                            -0.184221
#
#                                                      turnout  \
# Unnamed: 0                                          0.083252
# %_english_is_first_language_of_no_one_in_househ... -0.251114
# median_house_price_2014                             0.262742
# income                                              0.510309
# male_life_expectancy_2009_13                        0.399158
# female_life_expectancy_2009_13                      0.348662
# %_area_that_is_open_space_2014                     -0.009107
# %_travel_by_bicycle_to_work_2011                    0.279535
# turnout                                             1.000000
# crime_rate_2014_15                                 -0.166127
# %_bame_2011                                        -0.320853
# %_all_older_people_aged_65_2015                     0.327602
# %_homes_with_good_access_to_nature                  0.124595
# %_homes_with_deficiency_in_access_to_nature        -0.124595
# female_life_expectancy_normalised                   0.348662
# male_life_expectancy_normalised                     0.399158
#
#                                                     crime_rate_2014_15  \
# Unnamed: 0                                                    0.121451
# %_english_is_first_language_of_no_one_in_househ...            0.251044
# median_house_price_2014                                       0.302794
# income                                                        0.075341
# male_life_expectancy_2009_13                                 -0.074633
# female_life_expectancy_2009_13                               -0.053537
# %_area_that_is_open_space_2014                               -0.165776
# %_travel_by_bicycle_to_work_2011                              0.165574
# turnout                                                      -0.166127
# crime_rate_2014_15                                            1.000000
# %_bame_2011                                                   0.079508
# %_all_older_people_aged_65_2015                              -0.245868
# %_homes_with_good_access_to_nature                           -0.150034
# %_homes_with_deficiency_in_access_to_nature                   0.150034
# female_life_expectancy_normalised                            -0.053537
# male_life_expectancy_normalised                              -0.074633
#
#                                                     %_bame_2011  \
# Unnamed: 0                                             0.060438
# %_english_is_first_language_of_no_one_in_househ...     0.749317
# median_house_price_2014                               -0.278767
# income                                                -0.588628
# male_life_expectancy_2009_13                          -0.333248
# female_life_expectancy_2009_13                        -0.268129
# %_area_that_is_open_space_2014                        -0.243978
# %_travel_by_bicycle_to_work_2011                      -0.094914
# turnout                                               -0.320853
# crime_rate_2014_15                                     0.079508
# %_bame_2011                                            1.000000
# %_all_older_people_aged_65_2015                       -0.561248
# %_homes_with_good_access_to_nature                    -0.204318
# %_homes_with_deficiency_in_access_to_nature            0.204318
# female_life_expectancy_normalised                     -0.268129
# male_life_expectancy_normalised                       -0.333248
#
#                                                     %_all_older_people_aged_65_2015  \
# Unnamed: 0                                                                -0.255443
# %_english_is_first_language_of_no_one_in_househ...                        -0.543030
# median_house_price_2014                                                    0.085899
# income                                                                     0.338609
# male_life_expectancy_2009_13                                               0.525190
# female_life_expectancy_2009_13                                             0.393078
# %_area_that_is_open_space_2014                                             0.346641
# %_travel_by_bicycle_to_work_2011                                          -0.443925
# turnout                                                                    0.327602
# crime_rate_2014_15                                                        -0.245868
# %_bame_2011                                                               -0.561248
# %_all_older_people_aged_65_2015                                            1.000000
# %_homes_with_good_access_to_nature                                         0.180941
# %_homes_with_deficiency_in_access_to_nature                               -0.180941
# female_life_expectancy_normalised                                          0.393078
# male_life_expectancy_normalised                                            0.525190
#
#                                                     %_homes_with_good_access_to_nature  \
# Unnamed: 0                                                                   -0.024884
# %_english_is_first_language_of_no_one_in_househ...                           -0.208124
# median_house_price_2014                                                       0.077526
# income                                                                        0.168295
# male_life_expectancy_2009_13                                                  0.141751
# female_life_expectancy_2009_13                                                0.105695
# %_area_that_is_open_space_2014                                                0.239199
# %_travel_by_bicycle_to_work_2011                                              0.000637
# turnout                                                                       0.124595
# crime_rate_2014_15                                                           -0.150034
# %_bame_2011                                                                  -0.204318
# %_all_older_people_aged_65_2015                                               0.180941
# %_homes_with_good_access_to_nature                                            1.000000
# %_homes_with_deficiency_in_access_to_nature                                  -1.000000
# female_life_expectancy_normalised                                             0.105695
# male_life_expectancy_normalised                                               0.141751
#
#                                                     %_homes_with_deficiency_in_access_to_nature  \
# Unnamed: 0                                                                             0.024884
# %_english_is_first_language_of_no_one_in_househ...                                     0.208124
# median_house_price_2014                                                               -0.077526
# income                                                                                -0.168295
# male_life_expectancy_2009_13                                                          -0.141751
# female_life_expectancy_2009_13                                                        -0.105695
# %_area_that_is_open_space_2014                                                        -0.239199
# %_travel_by_bicycle_to_work_2011                                                      -0.000637
# turnout                                                                               -0.124595
# crime_rate_2014_15                                                                     0.150034
# %_bame_2011                                                                            0.204318
# %_all_older_people_aged_65_2015                                                       -0.180941
# %_homes_with_good_access_to_nature                                                    -1.000000
# %_homes_with_deficiency_in_access_to_nature                                            1.000000
# female_life_expectancy_normalised                                                     -0.105695
# male_life_expectancy_normalised                                                       -0.141751
#
#                                                     female_life_expectancy_normalised  \
# Unnamed: 0                                                                  -0.036006
# %_english_is_first_language_of_no_one_in_househ...                          -0.069790
# median_house_price_2014                                                      0.406423
# income                                                                       0.506527
# male_life_expectancy_2009_13                                                 0.705725
# female_life_expectancy_2009_13                                               1.000000
# %_area_that_is_open_space_2014                                               0.036027
# %_travel_by_bicycle_to_work_2011                                            -0.050849
# turnout                                                                      0.348662
# crime_rate_2014_15                                                          -0.053537
# %_bame_2011                                                                 -0.268129
# %_all_older_people_aged_65_2015                                              0.393078
# %_homes_with_good_access_to_nature                                           0.105695
# %_homes_with_deficiency_in_access_to_nature                                 -0.105695
# female_life_expectancy_normalised                                            1.000000
# male_life_expectancy_normalised                                              0.705725
#
#                                                     male_life_expectancy_normalised
# Unnamed: 0                                                                -0.030050
# %_english_is_first_language_of_no_one_in_househ...                        -0.103185
# median_house_price_2014                                                    0.460097
# income                                                                     0.648198
# male_life_expectancy_2009_13                                               1.000000
# female_life_expectancy_2009_13                                             0.705725
# %_area_that_is_open_space_2014                                             0.076994
# %_travel_by_bicycle_to_work_2011                                          -0.184221
# turnout                                                                    0.399158
# crime_rate_2014_15                                                        -0.074633
# %_bame_2011                                                               -0.333248
# %_all_older_people_aged_65_2015                                            0.525190
# %_homes_with_good_access_to_nature                                         0.141751
# %_homes_with_deficiency_in_access_to_nature                               -0.141751
# female_life_expectancy_normalised                                          0.705725
# male_life_expectancy_normalised                                            1.000000

# %%
reg_income = smf.ols(formula = 'turnout ~ income', data = df).fit()
print(reg_income.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                turnout   R-squared:                       0.260
# Model:                            OLS   Adj. R-squared:                  0.259
# Method:                 Least Squares   F-statistic:                     219.0
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):           1.12e-42
# Time:                        14:21:05   Log-Likelihood:                -1835.7
# No. Observations:                 624   AIC:                             3675.
# Df Residuals:                     622   BIC:                             3684.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     19.6911      0.993     19.827      0.000      17.741      21.641
# income         0.0004   2.49e-05     14.799      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                       78.201   Durbin-Watson:                   1.226
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              128.703
# Skew:                          -0.807   Prob(JB):                     1.13e-28
# Kurtosis:                       4.532   Cond. No.                     2.16e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.16e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
beta_0, beta_1 = reg_income.params
rsq    = reg_income.rsquared
pval_0, pval_1 = reg_income.pvalues

# %%
print("y =", round(beta_1,3), "x +", round(beta_0,3))
print("R^2 = ", rsq)
print("p-value of turnout = ", round(pval_1,5))
print("p-value of income = ", round(pval_0,5))
# Out:
# y = 0.0 x + 19.691
# R^2 =  0.2604148271221467
# p-value of turnout =  0.0
# p-value of income =  0.0

# %%
fig, ax = plt.subplots()
df.plot(kind='scatter', x='income', y='turnout', figsize=(20, 12), ax = ax)

X=df.income
b = plt.plot(X, X*beta_1 + beta_0, 'r') # Plot the regression line.

print("y =", round(beta_1,3), "x +", round(beta_0,3))
print("Rsq = ", rsq)
print("p-value of income = ", pval_1)
# Out:
# y = 0.0 x + 19.691
# Rsq =  0.2604148271221467
# p-value of income =  1.1230825645670539e-42

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 624 entries, 0 to 623
# Data columns (total 18 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Unnamed: 0                                               624 non-null    int64
#  1   ward                                                     624 non-null    object
#  2   borough                                                  624 non-null    object
#  3   %_english_is_first_language_of_no_one_in_household_2011  624 non-null    float64
#  4   median_house_price_2014                                  624 non-null    float64
#  5   income                                                   624 non-null    float64
#  6   male_life_expectancy_2009_13                             624 non-null    float64
#  7   female_life_expectancy_2009_13                           624 non-null    float64
#  8   %_area_that_is_open_space_2014                           624 non-null    float64
#  9   %_travel_by_bicycle_to_work_2011                         624 non-null    float64
#  10  turnout                                                  624 non-null    float64
#  11  crime_rate_2014_15                                       624 non-null    float64
#  12  %_bame_2011                                              624 non-null    float64
#  13  %_all_older_people_aged_65_2015                          624 non-null    float64
#  14  %_homes_with_good_access_to_nature                       624 non-null    float64
#  15  %_homes_with_deficiency_in_access_to_nature              624 non-null    float64
#  16  female_life_expectancy_normalised                        624 non-null    float64
#  17  male_life_expectancy_normalised                          624 non-null    float64
# dtypes: float64(15), int64(1), object(2)
# memory usage: 87.9+ KB

# %%
df.head()
# Out:
#    Unnamed: 0       ward               borough  \
# 0           1  E05000026  Barking and Dagenham
# 1           2  E05000027  Barking and Dagenham
# 2           3  E05000028  Barking and Dagenham
# 3           4  E05000029  Barking and Dagenham
# 4           5  E05000030  Barking and Dagenham
#
#    %_english_is_first_language_of_no_one_in_household_2011  \
# 0                                               25.7
# 1                                                7.9
# 2                                               10.5
# 3                                                6.5
# 4                                                4.5
#
#    median_house_price_2014   income  male_life_expectancy_2009_13  \
# 0                 173000.0  33920.0                          80.2
# 1                 215000.0  32470.0                          77.2
# 2                 210000.0  33000.0                          79.0
# 3                 240500.0  33920.0                          79.2
# 4                 240000.0  37400.0                          77.1
#
#    female_life_expectancy_2009_13  %_area_that_is_open_space_2014  \
# 0                            83.9                            21.9
# 1                            80.6                            20.6
# 2                            79.3                             1.9
# 3                            82.2                            56.0
# 4                            81.1                            50.4
#
#    %_travel_by_bicycle_to_work_2011  turnout  crime_rate_2014_15  %_bame_2011  \
# 0                               0.8     25.7               138.1         71.9
# 1                               1.0     20.3                73.6         29.9
# 2                               1.6     22.5                79.9         41.2
# 3                               1.2     25.3                76.1         37.9
# 4                               1.6     24.1                66.7         24.8
#
#    %_all_older_people_aged_65_2015  %_homes_with_good_access_to_nature  \
# 0                              5.0                                98.0
# 1                             10.0                                28.0
# 2                              8.7                                83.0
# 3                             14.2                                36.0
# 4                             14.2                               100.0
#
#    %_homes_with_deficiency_in_access_to_nature  \
# 0                                          2.0
# 1                                         72.0
# 2                                         17.0
# 3                                         64.0
# 4                                          0.0
#
#    female_life_expectancy_normalised  male_life_expectancy_normalised
# 0                           0.996498                         1.005313
# 1                           0.957303                         0.967708
# 2                           0.941863                         0.990271
# 3                           0.976306                         0.992778
# 4                           0.963242                         0.966455
